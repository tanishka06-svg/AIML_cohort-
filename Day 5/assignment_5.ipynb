# %% [markdown]
# Name:Tanishka Sanjay Shirode
#
# Batch: AIML
#
# Day:5 (12-8-26)
#
# Assignment No: 5

# %%
def add(a,b):
  return a+b
print(add(2,3))
# Out:
# 5

# %%
def add(a:int,b:int):
  return a+b

# %%
#Hinting a variable's type

name:str="abc"
age:int=20
height:float=5.4
is_student:bool=True
score:int

# %%
# Hinting what a function Returns

def square(number:int)->int:# -> placed after the parameters before the colon. it says what the function hands back
  return number*number
def get_name()-> str:
  return "Zophie"

# %%
def print_id(user_id:int|str):
  print(user_id)
print_id(101)
print_id("A101")
# Out:
# 101
# A101

# %%
num:list[int]=[10,20,30]
marks:dict[str,int]={"John":90}
point:tuple[int,int]=(20,30)

# %% [markdown]
# Type Hints in python hints what type of data a function should return. Even if we don't give the expected data according to the type hints it never throws an error.
#
# They are just given for what data is expected by the programmer or for the understanding purpose

# %%
def double(num:int)->int: #Shows that the function is expected to return integer value
  return num*2
double("Hii")

# Even thoough we gave string input it didn't thew any error
# Out:
# 'HiiHii'

# %%
def cal_avg(marks:list[int])->float: # Shows function should return float value
  return sum(marks)/len(marks)

def display_student(name:str,marks:list[int])->None: # none shows that the function can return any type of data
  avg:float=cal_avg(marks) #Function call
  print(f"Student:{name}")
  print(f"Average:{avg:2f}")

display_student("John",[90,80,70])
# Out:
# Student:John
# Average:80.000000

# %% [markdown]
# Syntax: class class_name:
#
#            class_body
#
# syntax for object:  object_name = class_name

# %%
# Creating a class and it's Object
class  Student:
  pass
student1=Student()
student2=Student()

# %%
student=Student()
student.name="John"
student.age=20
student.marks=90
print(student.name)
print(student.age)
print(student.marks)
# Out:
# John
# 20
# 90

# %%
#__init__() Used to initialize the attributes dynamically
class Student:
  def __init__(self,name,age):
    self.name=name
    self.age=age
student=Student("John",20)

# %%
# Method: a function that lives in a class
class Student:
  def __init__(self,name,age):
    self.name=name
    self.age=age
  def introduce(self): #Method
    print(f"My name is {self.name}")
    print(f"I am {self.age} years old")
student=Student("Tanishka",20)
student.introduce()
# Out:
# My name is Tanishka
# I am 20 years old

# %%
class BankAccount:
  def __init__(self,owner,balance):
    self.owner=owner
    self.balance=balance
  def deposit(self,amount):
    self.balance+=amount
  def withdraw(self,amount):
    if amount<=self.balance:
      self.balance-=amount
    else:
      print("Insufficient balance")

  def show_balance(self):
    print(f"Balance:{self.balance}")
account=BankAccount("Tanishka",1000)
account.deposit(1500)
account.withdraw(2000)
account.show_balance()
# Out:
# Balance:500

# %%
class Student:
    def __init__(self, name):
        self.name = name

    def __str__(self):
        return f"{self.name}"

    def __repr__(self):
      return f"{self.name!r}"

    def __len__(self):
        return len(self.name)

student = Student("Tanishka")

print(student)
print(repr(student))
print(len(student))
# Out:
# Tanishka
# 'Tanishka'
# 8
